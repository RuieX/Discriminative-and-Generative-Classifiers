# %% [markdown]
# # Models Comparison

# %% [markdown]
# # Setup
# Let us import the required modules.

# %%
import src.utilities.evaluation as eva

# %%
all_models = eva.ModelsComparison()

# %% [markdown]
# ## Best Performing Model

# %%
m, score = all_models.rank_model()
print("Best Model on Testing: {} \nwith Accuracy Score: {}".format(m,score))
# Out:
# Best Model on Testing: SVC(C=0.1, degree=2, gamma=0.1, kernel='poly')
# with Accuracy Score: 0.9796

# %%
all_models.get_performance_df()
# Out:
#                model  Accuracy Score
# 0          svclinear          0.9407
# 1      svcpolynomial          0.9796
# 2             svcrbf          0.9589
# 3       randomforest          0.9044
# 4  knearestneighbors          0.9707
# 5    beta_naivebayes          0.0992

# %%
all_models.performance_plot()
# Out:
# <AxesSubplot:xlabel='model', ylabel='Accuracy Score'>
